# %% [markdown]
# # CRISP - DM Methodology Individual Project.
# #### Involves:
# ##### Business Understanding, Data Understanding, Data Preparation, Modeling, Evaluation and lastly Deployment.
#
# ## Business Understanding
# #### The business wants to determine which province whether urban or rural to promote their products of roofing materials to.
# #### Assess regions with the highest to the lowest sales or demand for roofing materials.
# #### Determine regions to concentrate on promotion of their products
#
# ## Data Preparation throught Data Understanding as follows
# ##### Throught selection, cleaning, feature engineering, integration and formating.
#
# ### Importing libraries to be used in data analysis.

# %%
#importing our libraries
import pandas as pd

import numpy as np 

import matplotlib.pyplot as plt

import seaborn as sns

# %%
# loading the dataset
roofing = pd.read_csv("C:\data\Roofing_Material.csv")

roofing
# Out:
#             District rural/urban %_of_Households_Corrugated_Iron_Sheets  \
# 0    NYANDARUA NORTH       Urban                                 91.08%
# 1    NYANDARUA SOUTH       Urban                                 95.38%
# 2        NYERI NORTH       Urban                                 90.28%
# 3        NYERI SOUTH       Urban                                 90.89%
# 4          KIRINYAGA       Urban                                 91.41%
# ..               ...         ...                                    ...
# 310            BUSIA       Rural                                 49.66%
# 311       TESO NORTH       Rural                                  29.2%
# 312            SAMIA       Rural                                 52.69%
# 313          BUNYALA       Rural                                 58.22%
# 314       TESO SOUTH       Rural                                 25.44%
#
#     %_of_Households_Tiles %_of_Households_Concrete  \
# ...

# %%
# display 5 top rows of the dataset
roofing.head()
# Out:
#           District rural/urban %_of_Households_Corrugated_Iron_Sheets  \
# 0  NYANDARUA NORTH       Urban                                 91.08%
# 1  NYANDARUA SOUTH       Urban                                 95.38%
# 2      NYERI NORTH       Urban                                 90.28%
# 3      NYERI SOUTH       Urban                                 90.89%
# 4        KIRINYAGA       Urban                                 91.41%
#
#   %_of_Households_Tiles %_of_Households_Concrete  \
# 0                 0.62%                    0.16%
# 1                 0.47%                     2.6%
# 2                 1.13%                    5.21%
# 3                  2.3%                    3.32%
# 4                 0.87%                    3.97%
#
#   Asbestos_%_of_Households_Sheets %_of_Households_Grass  \
# 0                           1.46%                 0.64%
# 1                           1.46%                 0.06%
# 2                           2.58%                 0.49%
# ...

# %%
# display bottom rows of the dataset
roofing.tail()
# Out:
#        District rural/urban %_of_Households_Corrugated_Iron_Sheets  \
# 310       BUSIA       Rural                                 49.66%
# 311  TESO NORTH       Rural                                  29.2%
# 312       SAMIA       Rural                                 52.69%
# 313     BUNYALA       Rural                                 58.22%
# 314  TESO SOUTH       Rural                                 25.44%
#
#     %_of_Households_Tiles %_of_Households_Concrete  \
# 310                 0.46%                    0.03%
# 311                 0.42%                    0.03%
# 312                 0.72%                    0.05%
# 313                  0.5%                    0.04%
# 314                 0.36%                    0.03%
#
#     Asbestos_%_of_Households_Sheets %_of_Households_Grass  \
# 310                           2.15%                47.44%
# 311                           1.22%                69.07%
# 312                           2.01%                44.16%
# ...

# %%
# getting to know about the data
roofing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 26 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   District                                315 non-null    object
#  1   rural/urban                             315 non-null    object
#  2   %_of_Households_Corrugated_Iron_Sheets  290 non-null    object
#  3   %_of_Households_Tiles                   290 non-null    object
#  4   %_of_Households_Concrete                290 non-null    object
#  5   Asbestos_%_of_Households_Sheets         290 non-null    object
#  6   %_of_Households_Grass                   290 non-null    object
#  7   %_of_Households_Makuti                  290 non-null    object
#  8   %_of_Households_Tin                     290 non-null    object
#  9   %_of_Households_Mud/Dung                290 non-null    object
# ...

# %%
#
roofing.describe()
# Out:
#           Households  No_Corrugated_Iron_Sheets      No_Tiles   No_Concrete  \
# count     315.000000                 315.000000    315.000000    315.000000
# mean    27739.990476               20313.085714    615.212698    988.504762
# std     36936.013962               27522.195495   2768.136884   7514.353880
# min         0.000000                   0.000000      0.000000      0.000000
# 25%      6122.500000                2249.500000     33.500000      6.000000
# 50%     19729.000000               12196.000000    141.000000     20.000000
# 75%     35903.500000               28711.500000    312.000000     68.500000
# max    369265.000000              234774.000000  29909.000000  95455.000000
#
#        No_Asbestos_Sheets      No_Grass     No_Makuti       No_Tin  \
# count          315.000000    315.000000    315.000000   315.000000
# mean           626.085714   3791.142857    898.860317    79.857143
# std           1173.119447   6472.772229   3537.392935   187.095505
# ...

# %%
# getting to know more about the dataset
roofing.shape
# Out:
# (315, 26)

# %%
# dropping irrelevant data
roofing_clean = roofing.drop(["Location_1"], axis = 1)
roofing_clean
# Out:
#             District rural/urban %_of_Households_Corrugated_Iron_Sheets  \
# 0    NYANDARUA NORTH       Urban                                 91.08%
# 1    NYANDARUA SOUTH       Urban                                 95.38%
# 2        NYERI NORTH       Urban                                 90.28%
# 3        NYERI SOUTH       Urban                                 90.89%
# 4          KIRINYAGA       Urban                                 91.41%
# ..               ...         ...                                    ...
# 310            BUSIA       Rural                                 49.66%
# 311       TESO NORTH       Rural                                  29.2%
# 312            SAMIA       Rural                                 52.69%
# 313          BUNYALA       Rural                                 58.22%
# 314       TESO SOUTH       Rural                                 25.44%
#
#     %_of_Households_Tiles %_of_Households_Concrete  \
# ...

# %%
# checking if there is null value
roofing_clean.isnull()
# Out:
#      District  rural/urban  %_of_Households_Corrugated_Iron_Sheets  \
# 0       False        False                                   False
# 1       False        False                                   False
# 2       False        False                                   False
# 3       False        False                                   False
# 4       False        False                                   False
# ..        ...          ...                                     ...
# 310     False        False                                   False
# 311     False        False                                   False
# 312     False        False                                   False
# 313     False        False                                   False
# 314     False        False                                   False
#
#      %_of_Households_Tiles  %_of_Households_Concrete  \
# 0                    False                     False
# ...

# %%
#sum of null values
roofing_clean.isnull().sum()
# Out:
# District                                   0
# rural/urban                                0
# %_of_Households_Corrugated_Iron_Sheets    25
# %_of_Households_Tiles                     25
# %_of_Households_Concrete                  25
# Asbestos_%_of_Households_Sheets           25
# %_of_Households_Grass                     25
# %_of_Households_Makuti                    25
# %_of_Households_Tin                       25
# %_of_Households_Mud/Dung                  25
# %_of_Households_Other                     25
# Households                                 0
# No_Corrugated_Iron_Sheets                  0
# No_Tiles                                   0
# No_Concrete                                0
# No_Asbestos_Sheets                         0
# No_Grass                                   0
# No_Makuti                                  0
# No_Tin                                     0
# No_Mud/Dung                                0
# No_Other                                   0
# ...

# %%
# checking on duplicates
roofing_clean.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 310    False
# 311    False
# 312    False
# 313    False
# 314    False
# Length: 315, dtype: bool

# %%
# how many duplicates there are
roofing_clean.duplicated().sum()
# Out:
# 0

# %%
#replace null values
roofing_cleaned = roofing_clean.fillna(0)

# %%
#checking if there are null vallues still
roofing_cleaned.isnull().sum()
# Out:
# District                                  0
# rural/urban                               0
# %_of_Households_Corrugated_Iron_Sheets    0
# %_of_Households_Tiles                     0
# %_of_Households_Concrete                  0
# Asbestos_%_of_Households_Sheets           0
# %_of_Households_Grass                     0
# %_of_Households_Makuti                    0
# %_of_Households_Tin                       0
# %_of_Households_Mud/Dung                  0
# %_of_Households_Other                     0
# Households                                0
# No_Corrugated_Iron_Sheets                 0
# No_Tiles                                  0
# No_Concrete                               0
# No_Asbestos_Sheets                        0
# No_Grass                                  0
# No_Makuti                                 0
# No_Tin                                    0
# No_Mud/Dung                               0
# No_Other                                  0
# ...

# %%
#selecting columns to be used in my analysis
roofing_cleaned[["District","rural/urban","%_of_Households_Corrugated_Iron_Sheets","County","Province"]]
# Out:
#             District rural/urban %_of_Households_Corrugated_Iron_Sheets  \
# 0    NYANDARUA NORTH       Urban                                 91.08%
# 1    NYANDARUA SOUTH       Urban                                 95.38%
# 2        NYERI NORTH       Urban                                 90.28%
# 3        NYERI SOUTH       Urban                                 90.89%
# 4          KIRINYAGA       Urban                                 91.41%
# ..               ...         ...                                    ...
# 310            BUSIA       Rural                                 49.66%
# 311       TESO NORTH       Rural                                  29.2%
# 312            SAMIA       Rural                                 52.69%
# 313          BUNYALA       Rural                                 58.22%
# 314       TESO SOUTH       Rural                                 25.44%
#
#         County Province
# 0    Nyandarua  CENTRAL
# 1    Nyandarua  CENTRAL
# 2        Nyeri  CENTRAL
# ...

# %%
# determining which province has a high % of households with corrugated iron sheets

roofing_cleaned.Province.hist()
plt.title("Provincial % of Households with Corrugated Iron Sheets")
plt.ylabel("% of Household with Corrugated Iron Sheets")
plt.xlabel("Province")
plt.grid(False)

# %% [markdown]
# ##### The histogram shows the region witht the highest % of households with corrugated iron sheets is Rift Valley while Nairobi has the lowest % of houses with corrugated iron sheets.
# ##### This may be due to various reasons such as Nairobi being an urban centre may have need for permanent roofing material types thus the company would have to invest in more permanent roofing products so as to increase sales in this region.
